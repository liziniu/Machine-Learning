# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn import datasets
boston = datasets.load_boston()

# %%
x, y = boston.data, boston.target 
print(x.shape)
print(y.shape)
# Out:
# (506, 13)
# (506,)

# %%
print(x.shape)
print(y.shape)
# Out:
# (506, 13)
# (506,)

# %%
plt.plot(x[:, 0], y)

# %%
m = x.shape[0]
b = np.ones(shape=(m, 1))
x = np.hstack((x, b))
print(x.shape)
# Out:
# (506, 14)

# %%
y = y.reshape(m, 1)
w = np.matmul(np.matmul(np.linalg.inv(np.matmul(x.T, x)), x.T), y)
print(w.shape)
# Out:
# (14, 1)

# %%
y_pred = np.matmul(x, w)
plt.plot(y, 'r', y_pred, 'b')
# Out:
# [<matplotlib.lines.Line2D at 0x1118dbe10>,
#  <matplotlib.lines.Line2D at 0x1118e3400>]
